# %% [markdown]
# ![image.png](attachment:c6e12e03-2af4-4b34-bcee-3895680fdffd.png)

# %% [markdown]
# ![image.png](attachment:d9903e12-ca41-416e-a63b-9be5c6a90041.png)

# %% [markdown]
# ![image.png](attachment:dd525358-b47f-4a52-9e3c-fb2ddf62e00b.png)

# %% [markdown]
# ![image.png](attachment:caf5cb95-1319-439b-917b-3e5dcc1fe00b.png)

# %% [markdown]
# ![image.png](attachment:91888e25-806e-426d-bc72-0520fd4f6cfd.png)
